# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Estruturas de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Listas;</li>
#   <li>Conjuntos;</li>
#   <li>Dicionários.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Listas

# %% [markdown]
# Criei uma lista chamada `filmes` com o nome dos 10 primeiros filmes mais bem avaliados no site no [IMDB](https://www.imdb.com/chart/top/). Imprima o resultado.

# %%
filmes = ['O Poderoso Chefão' , 'Um Sonho de Liberdade' , 'Batman - O Cavaleiro das Trevas' , 'O Poderoso Chefão II', '12 Homens e uma Sentença' ,
          'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei' , 'Pulp Fiction - Tempo de Violência' , 'O Senhor dos Anéis: A Sociedade do Anel' ,
          'Três Homens em Conflito']
print(filmes)
# Out:
# ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman - O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']

# %% [markdown]
# Simule a movimentação do *ranking*. Utilize os métodos `insert` e `pop` para trocar a posição do primeiro e do segundo filme da lista. Imprima o resultado.

# %%
filmes = ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman - O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença',
          'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel',
          'Três Homens em Conflito']

filme_1 = filmes.pop(0)
filmes.insert(1, filme_1)

print(filmes)
# Out:
# ['Um Sonho de Liberdade', 'O Poderoso Chefão', 'Batman - O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Conjuntos

# %% [markdown]
# Aconteceu um erro no seu *ranking*. Simule a duplicação dos três últimos filmes da lista. Imprima o resultado.

# %%
filmes = ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman - O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença',
          'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel',
          'Três Homens em Conflito']

ultimos_tres_filmes = filmes[-3:]
filmes.extend(ultimos_tres_filmes)
print(filmes)
# Out:
# ['O Poderoso Chefão', 'Um Sonho de Liberdade', 'Batman - O Cavaleiro das Trevas', 'O Poderoso Chefão II', '12 Homens e uma Sentença', 'A Lista de Schindler', 'O Senhor dos Anéis: O Retorno do Rei', 'Pulp Fiction - Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito', 'Pulp Fiction - Tempo de Violência', 'O Senhor dos Anéis: A Sociedade do Anel', 'Três Homens em Conflito']

# %% [markdown]
# Utiliza a conversão `set` e `list` para remover os valores duplicados. Imprima o resultado.

# %%
convercao= set(filmes)
lista= list(convercao)
print(convercao)
print(lista)
# Out:
# {'Batman - O Cavaleiro das Trevas', 'O Senhor dos Anéis: A Sociedade do Anel', 'O Poderoso Chefão II', 'O Senhor dos Anéis: O Retorno do Rei', 'A Lista de Schindler', 'O Poderoso Chefão', 'Um Sonho de Liberdade', 'Pulp Fiction - Tempo de Violência', 'Três Homens em Conflito', '12 Homens e uma Sentença'}
# ['Batman - O Cavaleiro das Trevas', 'O Senhor dos Anéis: A Sociedade do Anel', 'O Poderoso Chefão II', 'O Senhor dos Anéis: O Retorno do Rei', 'A Lista de Schindler', 'O Poderoso Chefão', 'Um Sonho de Liberdade', 'Pulp Fiction - Tempo de Violência', 'Três Homens em Conflito', '12 Homens e uma Sentença']

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Dicionários

# %% [markdown]
# Repita os exercícios da parte 1 (listas). Os elementos da lista `filmes` devem ser dicionários no seguinte formato: `{'nome': <nome-do-filme>, 'ano': <ano do filme>}, 'sinopse': <sinopse do filme>}`.

# %%
dicio=[

    {
    'nome': 'O Poderoso Chefão',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'Um Sonho de Liberdade',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'Batman - O Cavaleiro das Trevas',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'Batman - O Cavaleiro das Trevas',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'O Poderoso Chefão II',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'O Poderoso Chefão',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': '12 Homens e uma Sentença',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'Batman - O Cavaleiro das Trevas',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'Um Sonho de Liberdade',
    'ano': 2000,
    'sinopse': 'lorem',
    },
    {
    'nome': 'O Poderoso Chefão',
    'ano': 2000,
    'sinopse': 'lorem',
    },

]
print(dicio)
# Out:
# [{'nome': 'O Poderoso Chefão', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'Um Sonho de Liberdade', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'Batman - O Cavaleiro das Trevas', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'Batman - O Cavaleiro das Trevas', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'O Poderoso Chefão II', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'O Poderoso Chefão', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': '12 Homens e uma Sentença', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'Batman - O Cavaleiro das Trevas', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'Um Sonho de Liberdade', 'ano': 2000, 'sinopse': 'lorem'}, {'nome': 'O Poderoso Chefão', 'ano': 2000, 'sinopse': 'lorem'}]
