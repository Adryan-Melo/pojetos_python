# %%
print('ola,mundo')
# Out:
# ola,mundo

# %% [markdown]
# ![Captura de tela 2024-01-16 112057.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# (A)
qtv=3
tm=320.52
r= (tm)/(qtv)
print(('O valor total de Vendas é:'), r)
# Out:
# O valor total de Venda é: 106.83999999999999

# %%
# (B)
vtv=834.47
tm=119.21
r= (vtv)/(tm)
print(('A Qdt de Vendas é:'), r)
# Out:
# A Qdt de Vendas é: 7.000000000000001

# %%
# (C)
vtv=834.47
qtv=5
r= (qtv)*(vtv)
print(('O ticket medio de Vendas é:'), r)
# Out:
# O ticket medio de Vendas é: 4172.35

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

r1=cancao.upper()
r2=cancao.isnumeric()
r3=cancao.isspace()

print(r1)
print(r2)
print(r3)
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# False
# False

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'


selic=noticia[12:17]
ano=noticia[-7:-6]
print(selic)
print(ano)
# Out:
# 2,75%
# 6

# %%
a = False
b = True

x = not a & b

print(x)
# Out:
# True
